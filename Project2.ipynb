# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnKundrat/MySecondProject/blob/main/Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Prompt user with the Intro for the Game

print("Welcome the Town of Hungerville!")
print("There is one hundred people with you. . .")
print("They are all very hungry.  . . ")
print("But you're the only one who can work. . ! ")
print("You will need to find a way to feed them or they may starve!")
print("You should find some food. . .")
print(". . .")
print("Like now!")
print("")



#Prompt user to select their "activity" to find food - either through Fishing, Hunting, or Gathering and standardize selection as lowercase

activity = input("You can: \n \n (a) Fish \n (b) Hunt in the forest \n (c) Gather \n \n Please select your choice: (a) - (c): ")
activity = activity.lower()

#Option 'a' - Fishing

print("")
if activity == "a":
    print("You picked Fishing. . .")
    print("Where would you like to go Fishing?")
    print("")
    fishingChoice = input("(a) The tiny pond \n(b) The frozen lake \n(c) The big fruitful ocean \n \n Please select your choice: ")
    fishingChoice = fishingChoice.lower()

    if fishingChoice == "a":
            print("\nYou go fishing in the tiny pond. It has a few small fish which you manage to catch.. . You come back to the town with just twothe  small fish which the cats immediately eat. \n Unfortunately, everyone dies of starvation. Hope you make a better choice next time! \n The End!")
    elif fishingChoice == "b":
            print("\nYou go to the lake. You can see many fish swimming but the lake is frozen over and you cannot get to them. After trying all night you come back to the town without a single fish. \n Unfortunately, everyone died of starvation. Hope you make a better choice next time! \n The End!")
    elif fishingChoice == "c":
            print("\nYou go to the vast ocean. . . \n Oddly, a Sailor with a large fishing vessel is waiting to take you out to sea. He provides you with a giant net which you cast out, catching hundreds of fish while enjoying a perfect sunny day. Well done, you saved the town! \n The End!")




#Option 'b' - Hunting

elif activity == "b":





    #prompt user with the premise of the deer hunting "game"

    print("You picked Hunting. . .!")
    print("As you enter the Forest with your bow and arrow, you see a huge deer run by at 30 miles per hour. It looks like it could feed the whole town!")
    print("Since the deer got a head start, you will have to shoot the arrow faster than the deer to catch it. . .")

    #prompt user for game arrow speed and set game conditions

    deerSpeed = int(30)
    arrowSpeed = int(input("How many miles per hour would you like to shoot your arrow? "))
    SuccessfulHunt = arrowSpeed > deerSpeed
    neverEndingHuntEasterEgg = arrowSpeed == deerSpeed


    #run game / conditional results

    if (SuccessfulHunt):
        print(f"The arrow slings forward with immense speed, at {arrowSpeed} miles per hour, and striking the deer.")
        print("While you feel sad for the deer (R.I.P.), you can't help but feel glad that everyone can eat, and you saved Hungerville.")
        print("The End!")
    elif (neverEndingHuntEasterEgg):
        print("You shoot the arrow forward at the same speed as the deer")
        print("The arrow and the deer are traveling at the same speed. . . ")
        print("You watch. . .")
        print("and watch . . ")
        print("But hours go by and the arrow never catches the deer")
        print("Impressive from the deer, but nightfalls and the town starves . . .")
        print(". . . and so do you! ")
        print("The End!")
    else:
        print("You didn't shoot the arrow fast enough to catch the deer. . . ")
        print("The deer escapes. . . ")
        print("Oh dear, that was the only deer in the forest. . .")
        print("Unfortunately, there's no other food and the town starves. . . ")
        print("The End!")


#Option 'c' - Gathering

elif activity == "c":
    #prompt user with berry collecting game instructions
    print("You chose to gathering . . . for berries!")
    print("As you go along the path, you see three gigantic bushes, filled with berries. ")
    print("You look closer and see a Redberry Bush, a Blueberry Bush, and a Greenberry Bush! YUM!")
    print("In order to feed the town you have to pick exactly 100 berries in total (Hungerville is very particular despite their hunger)")
    print("Also, you have to pick at least 5 Green Berries, but no more than 20. . .")
    print("")



    #uake user inputs for variables in the game.

    redBerries = int(input("How many Red Berries would you like to pick? " ))
    blueBerries = int(input ("How many Blue Berries would you like to pick? " ))
    greenBerries = int(input("How many Green Berries would you like to pick? " ))


     #set conditions for a success game / "win" based on previously offered instructions

    successfulGather = redBerries + blueBerries + greenBerries == 100 and  greenBerries >= 5 and greenBerries <= 20

    #determine if player won or loss:

    if successfulGather:
        print("That works. You take all the berries back to town and everyone feasts!")
    else:
        print("hmm, that combination didn't work. . . \n As you go back to try again, you notice all the berries dried up. Tough news for Hungerville. The End!")
